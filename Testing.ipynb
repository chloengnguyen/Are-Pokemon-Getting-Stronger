# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('old_gen_wdup.csv', index_col = None)

# %%
df = df.drop("Unnamed: 0", axis = 1)

# %%
df
# Out:
#       ID                    NAME          TYPE  BASE STAT     HP  ATTACK  \
# 0      1               Bulbasaur  Grass Poison      318.0   45.0    49.0
# 1      2                 Ivysaur  Grass Poison      405.0   60.0    62.0
# 2      3                Venusaur  Grass Poison      525.0   80.0    82.0
# 3      3  Venusaur Mega Venusaur  Grass Poison      625.0   80.0   100.0
# 4      4              Charmander         Fire       309.0   39.0    52.0
# ..   ...                     ...           ...        ...    ...     ...
# 582  490                 Manaphy        Water       600.0  100.0   100.0
# 583  491                 Darkrai         Dark       600.0   70.0    90.0
# 584  492      Shaymin Land Forme        Grass       600.0  100.0   100.0
# 585  492       Shaymin Sky Forme  Grass Flying      600.0  100.0   103.0
# 586  493                  Arceus       Normal       720.0  120.0   120.0
#
#      DEFENSE  SP ATTACK  SP DEFENSE  SPEED
# 0       49.0       65.0        65.0   45.0
# ...

# %%
unq, count = np.unique(df.ID, axis=0, return_counts=True)

# %%
unq[count>1]
# Out:
# array([  3,   6,   9,  15,  18,  19,  20,  25,  26,  27,  28,  37,  38,
#         50,  51,  52,  53,  65,  74,  75,  76,  77,  78,  79,  80,  83,
#         88,  89,  94, 103, 105, 110, 115, 122, 127, 130, 133, 142, 150,
#        181, 208, 212, 214, 222, 229, 248, 254, 257, 260, 263, 264, 282,
#        302, 303, 306, 308, 310, 319, 323, 334, 351, 354, 359, 362, 373,
#        376, 380, 381, 382, 383, 384, 386, 413, 428, 445, 448, 460, 475,
#        479, 487, 492])

# %%
first_dup = df.duplicated(subset = 'ID', keep = False)

# %%
first_dup
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 582    False
# 583    False
# 584     True
# 585     True
# 586    False
# Length: 587, dtype: bool

# %%
duplicated = df[first_dup]
duplicated
# Out:
#       ID                        NAME            TYPE  BASE STAT     HP  \
# 2      3                    Venusaur    Grass Poison      525.0   80.0
# 3      3      Venusaur Mega Venusaur    Grass Poison      625.0   80.0
# 6      6                   Charizard     Fire Flying      534.0   78.0
# 7      6  Charizard Mega Charizard X     Fire Dragon      634.0   78.0
# 8      6  Charizard Mega Charizard Y     Fire Flying      634.0   78.0
# ..   ...                         ...             ...        ...    ...
# 570  479             Rotom Mow Rotom  Electric Grass      520.0   50.0
# 578  487      Giratina Altered Forme    Ghost Dragon      680.0  150.0
# 579  487       Giratina Origin Forme    Ghost Dragon      680.0  150.0
# 584  492          Shaymin Land Forme          Grass       600.0  100.0
# 585  492           Shaymin Sky Forme    Grass Flying      600.0  100.0
#
#      ATTACK  DEFENSE  SP ATTACK  SP DEFENSE  SPEED
# 2      82.0     83.0      100.0       100.0   80.0
# ...

# %%
dup_2 = duplicated.duplicated(subset = 'ID', keep = 'first')

# %%
dup_3 = duplicated[dup_2]
dup_3
# Out:
#       ID                        NAME             TYPE  BASE STAT     HP  \
# 3      3      Venusaur Mega Venusaur     Grass Poison      625.0   80.0
# 7      6  Charizard Mega Charizard X      Fire Dragon      634.0   78.0
# 8      6  Charizard Mega Charizard Y      Fire Flying      634.0   78.0
# 12     9    Blastoise Mega Blastoise           Water       630.0   79.0
# 19    15      Beedrill Mega Beedrill       Bug Poison      495.0   65.0
# ..   ...                         ...              ...        ...    ...
# 568  479           Rotom Frost Rotom     Electric Ice      520.0   50.0
# 569  479             Rotom Fan Rotom  Electric Flying      520.0   50.0
# 570  479             Rotom Mow Rotom   Electric Grass      520.0   50.0
# 579  487       Giratina Origin Forme     Ghost Dragon      680.0  150.0
# 585  492           Shaymin Sky Forme     Grass Flying      600.0  100.0
#
#      ATTACK  DEFENSE  SP ATTACK  SP DEFENSE  SPEED
# 3     100.0    123.0      122.0       120.0   80.0
# ...

# %%
idx = list(dup_3.index)

# %%
# Move these to the bottom of a main DF 
later_gen = df.loc[idx, :]
later_gen
# Out:
#       ID                        NAME             TYPE  BASE STAT     HP  \
# 3      3      Venusaur Mega Venusaur     Grass Poison      625.0   80.0
# 7      6  Charizard Mega Charizard X      Fire Dragon      634.0   78.0
# 8      6  Charizard Mega Charizard Y      Fire Flying      634.0   78.0
# 12     9    Blastoise Mega Blastoise           Water       630.0   79.0
# 19    15      Beedrill Mega Beedrill       Bug Poison      495.0   65.0
# ..   ...                         ...              ...        ...    ...
# 568  479           Rotom Frost Rotom     Electric Ice      520.0   50.0
# 569  479             Rotom Fan Rotom  Electric Flying      520.0   50.0
# 570  479             Rotom Mow Rotom   Electric Grass      520.0   50.0
# 579  487       Giratina Origin Forme     Ghost Dragon      680.0  150.0
# 585  492           Shaymin Sky Forme     Grass Flying      600.0  100.0
#
#      ATTACK  DEFENSE  SP ATTACK  SP DEFENSE  SPEED
# 3     100.0    123.0      122.0       120.0   80.0
# ...

# %%
early_gen = df.loc[idx, :]

# %%
df
# Out:
#       ID                    NAME          TYPE  BASE STAT     HP  ATTACK  \
# 0      1               Bulbasaur  Grass Poison      318.0   45.0    49.0
# 1      2                 Ivysaur  Grass Poison      405.0   60.0    62.0
# 2      3                Venusaur  Grass Poison      525.0   80.0    82.0
# 3      3  Venusaur Mega Venusaur  Grass Poison      625.0   80.0   100.0
# 4      4              Charmander         Fire       309.0   39.0    52.0
# ..   ...                     ...           ...        ...    ...     ...
# 582  490                 Manaphy        Water       600.0  100.0   100.0
# 583  491                 Darkrai         Dark       600.0   70.0    90.0
# 584  492      Shaymin Land Forme        Grass       600.0  100.0   100.0
# 585  492       Shaymin Sky Forme  Grass Flying      600.0  100.0   103.0
# 586  493                  Arceus       Normal       720.0  120.0   120.0
#
#      DEFENSE  SP ATTACK  SP DEFENSE  SPEED
# 0       49.0       65.0        65.0   45.0
# ...

# %%
mega = df[df['NAME'].str.contains('Mega ')]
mega
# Out:
#       ID                        NAME              TYPE  BASE STAT     HP  \
# 3      3      Venusaur Mega Venusaur      Grass Poison      625.0   80.0
# 7      6  Charizard Mega Charizard X       Fire Dragon      634.0   78.0
# 8      6  Charizard Mega Charizard Y       Fire Flying      634.0   78.0
# 12     9    Blastoise Mega Blastoise            Water       630.0   79.0
# 19    15      Beedrill Mega Beedrill        Bug Poison      495.0   65.0
# 23    18        Pidgeot Mega Pidgeot     Normal Flying      579.0   83.0
# 84    65      Alakazam Mega Alakazam          Psychic       600.0   55.0
# 106   80        Slowbro Mega Slowbro     Water Psychic      590.0   95.0
# 125   94          Gengar Mega Gengar      Ghost Poison      600.0   60.0
# 150  115  Kangaskhan Mega Kangaskhan           Normal       590.0  105.0
# 164  127          Pinsir Mega Pinsir        Bug Flying      600.0   65.0
# 168  130      Gyarados Mega Gyarados        Water Dark      640.0   95.0
# ...

# %%
idx = list(mega.index)

# %%
mega.to_csv("mega.csv", header = True)

# %%
pokemon = pd.read_csv('pokemon.csv', index_col = None)

# %%
pokemon = pokemon.drop('Unnamed: 0', axis = 1)

# %%
bad_df = pokemon.ID.isin(idx)

# %%
pokemon[~bad_df]
# Out:
#        ID                  NAME           TYPE  BASE STAT     HP  ATTACK  \
# 0       1             Bulbasaur   Grass Poison      318.0   45.0    49.0
# 1       2               Ivysaur   Grass Poison      405.0   60.0    62.0
# 4       4            Charmander          Fire       309.0   39.0    52.0
# 5       5            Charmeleon          Fire       405.0   58.0    64.0
# 6       6             Charizard    Fire Flying      534.0   78.0    84.0
# ...   ...                   ...            ...        ...    ...     ...
# 1040  896             Glastrier           Ice       580.0  100.0   145.0
# 1041  897             Spectrier         Ghost       580.0  100.0    65.0
# 1042  898               Calyrex  Psychic Grass      500.0  100.0    80.0
# 1043  898     Calyrex Ice Rider    Psychic Ice      680.0  100.0   165.0
# 1044  898  Calyrex Shadow Rider  Psychic Ghost      680.0  100.0    85.0
#
#       DEFENSE  SP ATTACK  SP DEFENSE  SPEED
# 0        49.0       65.0        65.0   45.0
# ...

# %%
old_stat = pd.read_csv('old_gen_wdup.csv', index_col = None)

# %%
old_stat = old_stat.drop('Unnamed: 0', axis = 1)

# %%
galarian = old_stat[old_stat['NAME'].str.contains('Galarian ')]

# %%
galarian
# Out:
#       ID                            NAME            TYPE  BASE STAT    HP  \
# 63    52          Meowth Galarian Meowth          Steel       290.0  50.0
# 93    77          Ponyta Galarian Ponyta        Psychic       410.0  50.0
# 95    78      Rapidash Galarian Rapidash   Psychic Fairy      500.0  65.0
# 97    79      Slowpoke Galarian Slowpoke        Psychic       315.0  90.0
# 99    80        Slowbro Galarian Slowbro  Poison Psychic      490.0  95.0
# 103   83  Farfetch'd Galarian Farfetch'd       Fighting       377.0  52.0
# 135  110        Weezing Galarian Weezing    Poison Fairy      490.0  65.0
# 148  122      Mr. Mime Galarian Mr. Mime     Psychic Ice      460.0  50.0
# 250  222        Corsola Galarian Corsola          Ghost       410.0  60.0
# 292  263    Zigzagoon Galarian Zigzagoon     Dark Normal      240.0  38.0
# 294  264        Linoone Galarian Linoone     Dark Normal      420.0  78.0
#
#      ATTACK  DEFENSE  SP ATTACK  SP DEFENSE  SPEED
# ...

# %%
galarian_idx = galarian.index
galarian_idx
# Out:
# Int64Index([63, 93, 95, 97, 99, 103, 135, 148, 250, 292, 294], dtype='int64')

# %%
old_stat.index.isin(galarian_idx)
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False,  True, False,  True, False,  True, False,
#         True, False, False, False,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
# ...

# %%
old_stat_upd = old_stat[~old_stat.index.isin(galarian_idx)]

# %%
old_stat_upd
# Out:
#       ID                NAME          TYPE  BASE STAT     HP  ATTACK  DEFENSE  \
# 0      1           Bulbasaur  Grass Poison      318.0   45.0    49.0     49.0
# 1      2             Ivysaur  Grass Poison      405.0   60.0    62.0     63.0
# 2      3            Venusaur  Grass Poison      525.0   80.0    82.0     83.0
# 3      4          Charmander         Fire       309.0   39.0    52.0     43.0
# 4      5          Charmeleon         Fire       405.0   58.0    64.0     58.0
# ..   ...                 ...           ...        ...    ...     ...      ...
# 536  490             Manaphy        Water       600.0  100.0   100.0    100.0
# 537  491             Darkrai         Dark       600.0   70.0    90.0     90.0
# 538  492  Shaymin Land Forme        Grass       600.0  100.0   100.0    100.0
# 539  492   Shaymin Sky Forme  Grass Flying      600.0  100.0   103.0     75.0
# 540  493              Arceus       Normal       720.0  120.0   120.0    120.0
#
# ...

# %%
old_stat_upd.to_csv("old_stat_upd.csv", header = True)

# %%
new_stat = pd.read_csv('new_gen.csv', index_col = None)

# %%
new_stat
# Out:
#      Unnamed: 0   ID                      NAME           TYPE  BASE STAT  \
# 0           545  457                  Lumineon         Water       460.0
# 1           546  458                   Mantyke   Water Flying      345.0
# 2           547  459                    Snover      Grass Ice      334.0
# 3           548  460                 Abomasnow      Grass Ice      494.0
# 4           549  460  Abomasnow Mega Abomasnow      Grass Ice      594.0
# ..          ...  ...                       ...            ...        ...
# 495        1040  896                 Glastrier           Ice       580.0
# 496        1041  897                 Spectrier         Ghost       580.0
# 497        1042  898                   Calyrex  Psychic Grass      500.0
# 498        1043  898         Calyrex Ice Rider    Psychic Ice      680.0
# 499        1044  898      Calyrex Shadow Rider  Psychic Ghost      680.0
#
#         HP  ATTACK  DEFENSE  SP ATTACK  SP DEFENSE  SPEED
# ...

# %%
main_df = pd.read_csv('main_df.csv', index_col = None)

# %%
main_df
# Out:
#      Unnamed: 0   ID                  NAME           TYPE  BASE STAT     HP  \
# 0             0    1             Bulbasaur   Grass Poison      318.0   45.0
# 1             1    2               Ivysaur   Grass Poison      405.0   60.0
# 2             2    3              Venusaur   Grass Poison      525.0   80.0
# 3             3    4            Charmander          Fire       309.0   39.0
# 4             4    5            Charmeleon          Fire       405.0   58.0
# ..          ...  ...                   ...            ...        ...    ...
# 988         988  896             Glastrier           Ice       580.0  100.0
# 989         989  897             Spectrier         Ghost       580.0  100.0
# 990         990  898               Calyrex  Psychic Grass      500.0  100.0
# 991         991  898     Calyrex Ice Rider    Psychic Ice      680.0  100.0
# 992         992  898  Calyrex Shadow Rider  Psychic Ghost      680.0  100.0
#
#      ATTACK  DEFENSE  SP ATTACK  SP DEFENSE  SPEED
# ...

# %%
main_df = main_df.drop("Unnamed: 0", axis =1)

# %%
df1 = main_df[:541]

# %%
df1
# Out:
#       ID                NAME          TYPE  BASE STAT     HP  ATTACK  DEFENSE  \
# 0      1           Bulbasaur  Grass Poison      318.0   45.0    49.0     49.0
# 1      2             Ivysaur  Grass Poison      405.0   60.0    62.0     63.0
# 2      3            Venusaur  Grass Poison      525.0   80.0    82.0     83.0
# 3      4          Charmander         Fire       309.0   39.0    52.0     43.0
# 4      5          Charmeleon         Fire       405.0   58.0    64.0     58.0
# ..   ...                 ...           ...        ...    ...     ...      ...
# 536  490             Manaphy        Water       600.0  100.0   100.0    100.0
# 537  491             Darkrai         Dark       600.0   70.0    90.0     90.0
# 538  492  Shaymin Land Forme        Grass       600.0  100.0   100.0    100.0
# 539  492   Shaymin Sky Forme  Grass Flying      600.0  100.0   103.0     75.0
# 540  493              Arceus       Normal       720.0  120.0   120.0    120.0
#
# ...

# %%
df2 = main_df[541:]

# %%
df2
# Out:
#       ID                  NAME           TYPE  BASE STAT     HP  ATTACK  \
# 541  494               Victini   Psychic Fire      600.0  100.0   100.0
# 542  495                 Snivy         Grass       308.0   45.0    45.0
# 543  496               Servine         Grass       413.0   60.0    60.0
# 544  497             Serperior         Grass       528.0   75.0    75.0
# 545  498                 Tepig          Fire       308.0   65.0    63.0
# ..   ...                   ...            ...        ...    ...     ...
# 988  896             Glastrier           Ice       580.0  100.0   145.0
# 989  897             Spectrier         Ghost       580.0  100.0    65.0
# 990  898               Calyrex  Psychic Grass      500.0  100.0    80.0
# 991  898     Calyrex Ice Rider    Psychic Ice      680.0  100.0   165.0
# 992  898  Calyrex Shadow Rider  Psychic Ghost      680.0  100.0    85.0
#
#      DEFENSE  SP ATTACK  SP DEFENSE  SPEED
# 541    100.0      100.0       100.0  100.0
# ...

# %%
df2 = pd.concat([df2,galarian])

# %%
df2
# Out:
#       ID                          NAME          TYPE  BASE STAT     HP  \
# 541  494                       Victini  Psychic Fire      600.0  100.0
# 542  495                         Snivy        Grass       308.0   45.0
# 543  496                       Servine        Grass       413.0   60.0
# 544  497                     Serperior        Grass       528.0   75.0
# 545  498                         Tepig         Fire       308.0   65.0
# ..   ...                           ...           ...        ...    ...
# 135  110      Weezing Galarian Weezing  Poison Fairy      490.0   65.0
# 148  122    Mr. Mime Galarian Mr. Mime   Psychic Ice      460.0   50.0
# 250  222      Corsola Galarian Corsola        Ghost       410.0   60.0
# 292  263  Zigzagoon Galarian Zigzagoon   Dark Normal      240.0   38.0
# 294  264      Linoone Galarian Linoone   Dark Normal      420.0   78.0
#
#      ATTACK  DEFENSE  SP ATTACK  SP DEFENSE  SPEED
# 541   100.0    100.0      100.0       100.0  100.0
# ...

# %%
df2.to_csv("new_stat_upd.csv", header = True)

# %%
base_old = list(old_stat_upd['BASE STAT'])
base_new = list(df2['BASE STAT'])

# %%
outliers=[]
def detect_outlier(data_1):
    
    threshold=3
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
    return outliers

# %%
detect_outlier(base_old)
# Out:
# [770.0, 770.0]

# %%
detect_outlier(base_new)
# Out:
# [770.0, 770.0, 1125.0]

# %%
base_new.remove(1125.0)

# %%
def welch_test_statistic(sample_1, sample_2):
    numerator = np.mean(sample_1) - np.mean(sample_2)
    denominator_sq = (np.var(sample_1) / len(sample_1)) + \
                        (np.var(sample_2) / len(sample_2))
    return numerator / np.sqrt(denominator_sq)

# %%
test_statistic = welch_test_statistic(base_old, base_new)
print("Welch Test Statistic: {:2.2f}".format(test_statistic))
# Out:
# Welch Test Statistic: -3.27

# %%
def welch_df(sample_1, sample_2):
    ss1 = len(sample_1)
    ss2 = len(sample_2)
    df = (
        ((np.var(sample_1)/ss1 + np.var(sample_2)/ss2)**(2.0)) / 
        ((np.var(sample_1)/ss1)**(2.0)/(ss1 - 1) + (np.var(sample_2)/ss2)**(2.0)/(ss2 - 1))
    )
    return df

# %%
dof = welch_df(base_old, base_new)
print("Degrees of Freedom for Welch's Test: {:2.2f}".format(dof))
# Out:
# Degrees of Freedom for Welch's Test: 964.89

# %%
from scipy import stats
# T-distribution
students = stats.t(dof)
pvalue = students.cdf(test_statistic) + (1 - students.cdf(-test_statistic))
print("p-value for different average total stats: {:2.9f}".format(pvalue))
# Out:
# p-value for different average total stats: 0.001125976

# %%
df = pd.read_csv('pokemon.csv', index_col = None)

# %%
df = df.drop('Unnamed: 0', axis = 1)

# %%
df
# Out:
#        ID                    NAME           TYPE  BASE STAT     HP  ATTACK  \
# 0       1               Bulbasaur   Grass Poison      318.0   45.0    49.0
# 1       2                 Ivysaur   Grass Poison      405.0   60.0    62.0
# 2       3                Venusaur   Grass Poison      525.0   80.0    82.0
# 3       3  Venusaur Mega Venusaur   Grass Poison      625.0   80.0   100.0
# 4       4              Charmander          Fire       309.0   39.0    52.0
# ...   ...                     ...            ...        ...    ...     ...
# 1040  896               Glastrier           Ice       580.0  100.0   145.0
# 1041  897               Spectrier         Ghost       580.0  100.0    65.0
# 1042  898                 Calyrex  Psychic Grass      500.0  100.0    80.0
# 1043  898       Calyrex Ice Rider    Psychic Ice      680.0  100.0   165.0
# 1044  898    Calyrex Shadow Rider  Psychic Ghost      680.0  100.0    85.0
#
#       DEFENSE  SP ATTACK  SP DEFENSE  SPEED
# ...

# %%
df.isnull().sum()
# Out:
# ID            0
# NAME          0
# TYPE          0
# BASE STAT     4
# HP            4
# ATTACK        4
# DEFENSE       4
# SP ATTACK     4
# SP DEFENSE    4
# SPEED         4
# dtype: int64

# %%
df = df.dropna()

# %%
combined_type = df.TYPE.str.split(" ", expand = True)

# %%
combined_type = combined_type.replace(r'\s+|^$', np.nan, regex=True)

# %%
combined_type.head(20)
# Out:
#         0       1
# 0   Grass  Poison
# 1   Grass  Poison
# 2   Grass  Poison
# 3   Grass  Poison
# 4    Fire     NaN
# 5    Fire     NaN
# 6    Fire  Flying
# 7    Fire  Dragon
# 8    Fire  Flying
# 9   Water     NaN
# 10  Water     NaN
# 11  Water     NaN
# 12  Water     NaN
# 13    Bug     NaN
# 14    Bug     NaN
# 15    Bug  Flying
# 16    Bug  Poison
# 17    Bug  Poison
# 18    Bug  Poison
# 19    Bug  Poison

# %%
df.insert(2, "TYPE1", combined_type[0], True)

# %%
df
# Out:
#        ID                    NAME    TYPE1           TYPE  BASE STAT     HP  \
# 0       1               Bulbasaur    Grass   Grass Poison      318.0   45.0
# 1       2                 Ivysaur    Grass   Grass Poison      405.0   60.0
# 2       3                Venusaur    Grass   Grass Poison      525.0   80.0
# 3       3  Venusaur Mega Venusaur    Grass   Grass Poison      625.0   80.0
# 4       4              Charmander     Fire          Fire       309.0   39.0
# ...   ...                     ...      ...            ...        ...    ...
# 1040  896               Glastrier      Ice           Ice       580.0  100.0
# 1041  897               Spectrier    Ghost         Ghost       580.0  100.0
# 1042  898                 Calyrex  Psychic  Psychic Grass      500.0  100.0
# 1043  898       Calyrex Ice Rider  Psychic    Psychic Ice      680.0  100.0
# 1044  898    Calyrex Shadow Rider  Psychic  Psychic Ghost      680.0  100.0
#
#       ATTACK  DEFENSE  SP ATTACK  SP DEFENSE  SPEED
# ...

# %%
df.insert(3, "TYPE2", combined_type[1], True)

# %%
df
# Out:
#        ID                    NAME    TYPE1   TYPE2           TYPE  BASE STAT  \
# 0       1               Bulbasaur    Grass  Poison   Grass Poison      318.0
# 1       2                 Ivysaur    Grass  Poison   Grass Poison      405.0
# 2       3                Venusaur    Grass  Poison   Grass Poison      525.0
# 3       3  Venusaur Mega Venusaur    Grass  Poison   Grass Poison      625.0
# 4       4              Charmander     Fire     NaN          Fire       309.0
# ...   ...                     ...      ...     ...            ...        ...
# 1040  896               Glastrier      Ice     NaN           Ice       580.0
# 1041  897               Spectrier    Ghost     NaN         Ghost       580.0
# 1042  898                 Calyrex  Psychic   Grass  Psychic Grass      500.0
# 1043  898       Calyrex Ice Rider  Psychic     Ice    Psychic Ice      680.0
# 1044  898    Calyrex Shadow Rider  Psychic   Ghost  Psychic Ghost      680.0
#
# ...

# %%
dual_types = df[df['TYPE2'] != np.nan]
dual_types
# Out:
#        ID                    NAME    TYPE1   TYPE2           TYPE  BASE STAT  \
# 0       1               Bulbasaur    Grass  Poison   Grass Poison      318.0
# 1       2                 Ivysaur    Grass  Poison   Grass Poison      405.0
# 2       3                Venusaur    Grass  Poison   Grass Poison      525.0
# 3       3  Venusaur Mega Venusaur    Grass  Poison   Grass Poison      625.0
# 4       4              Charmander     Fire     NaN          Fire       309.0
# ...   ...                     ...      ...     ...            ...        ...
# 1040  896               Glastrier      Ice     NaN           Ice       580.0
# 1041  897               Spectrier    Ghost     NaN         Ghost       580.0
# 1042  898                 Calyrex  Psychic   Grass  Psychic Grass      500.0
# 1043  898       Calyrex Ice Rider  Psychic     Ice    Psychic Ice      680.0
# 1044  898    Calyrex Shadow Rider  Psychic   Ghost  Psychic Ghost      680.0
#
# ...

# %% [markdown]
# ### Heat map for dual-type pokemon

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')

fig, ax = plt.subplots(figsize=(12,10))        
#sns.heatmap(df1.iloc[:, 1:6:], annot=True, linewidths=.5, ax=ax)
sns.heatmap(
    dual_types.groupby(['TYPE1', 'TYPE2']).size().unstack(),
    annot=True,
    linewidths=1,
    ax=ax
)
fig.savefig('dual-type.png')

# %% [markdown]
# ### Bar graph for single type

# %%
fig, ax = plt.subplots(figsize=(10,10))

plt.bar(
    list(df.TYPE1.unique()), 
    df.TYPE1.value_counts(), 
    color='red')
plt.xlabel("Type 1")
plt.ylabel("Num of Pokemon")
plt.title("Distribution of pokemon type")
# Out:
# Text(0.5, 1.0, 'Distribution of pokemon type')

# %%
fig, ax = plt.subplots(figsize=(10,10))

plt.barh(
    list(df.TYPE1.unique()), 
    df.TYPE1.value_counts(), 
    color='orange'
    
)
plt.gca().invert_yaxis() # Reverse the order 
plt.ylabel("Primary Type")
plt.xlabel("# of Pokemon")
plt.title("Primary Type of Pokemon Distribution")
plt.savefig('single_type_pokemon')

# %%
df_nd_type = df.copy()

# %%
df_nd_type['TYPE2'] = df_nd_type[['TYPE2']].fillna(value="None")

# %%
df_nd_type
# Out:
#        ID                    NAME    TYPE1   TYPE2           TYPE  BASE STAT  \
# 0       1               Bulbasaur    Grass  Poison   Grass Poison      318.0
# 1       2                 Ivysaur    Grass  Poison   Grass Poison      405.0
# 2       3                Venusaur    Grass  Poison   Grass Poison      525.0
# 3       3  Venusaur Mega Venusaur    Grass  Poison   Grass Poison      625.0
# 4       4              Charmander     Fire    None          Fire       309.0
# ...   ...                     ...      ...     ...            ...        ...
# 1040  896               Glastrier      Ice    None           Ice       580.0
# 1041  897               Spectrier    Ghost    None         Ghost       580.0
# 1042  898                 Calyrex  Psychic   Grass  Psychic Grass      500.0
# 1043  898       Calyrex Ice Rider  Psychic     Ice    Psychic Ice      680.0
# 1044  898    Calyrex Shadow Rider  Psychic   Ghost  Psychic Ghost      680.0
#
# ...

# %%
# Error, there is nan values in TYPE 2!!!
fig, ax = plt.subplots(figsize=(10,10))

plt.barh(
    list(df_nd_type.TYPE2.unique()), 
    df_nd_type.TYPE2.value_counts(), 
    color='orange')
plt.gca().invert_yaxis() # Reverse the order 
plt.ylabel("Secondary Type")
plt.xlabel("# of Pokemon")
plt.title("Pokemon Secondary Type Distribution")
plt.savefig('secondary_type_pokemon')

# %% [markdown]
# ### Combined bar chart for common type?

# %%
main_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-101-a7bf8065ec73> in <module>
# ----> 1 main_df
#
# NameError: name 'main_df' is not defined

# %%
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
# Out:
# Generation
# 1    426.813253
# 2    418.283019
# 3    436.225000
# 4    459.016529
# 5    434.987879
# 6    436.378049
# Name: Total, dtype: float64

# %%
def add_value_labels(ax, spacing=5):
    """Add labels to the end of each bar in a bar chart.

    Arguments:
        ax (matplotlib.axes.Axes): The matplotlib object containing the axes
            of the plot to annotate.
        spacing (int): The distance between the labels and the bars.
    """

    # For each bar: Place a label
    for rect in ax.patches:
        # Get X and Y placement of label from rect.
        y_value = rect.get_height()
        x_value = rect.get_x() + rect.get_width() / 2

        # Number of points between bar and label. Change to your liking.
        space = spacing
        # Vertical alignment for positive values
        va = 'bottom'

        # If value of bar is negative: Place label below bar
        if y_value < 0:
            # Invert space to place label below
            space *= -1
            # Vertically align label at top
            va = 'top'

        # Use Y value as label and format number with one decimal place
        label = "{:.1f}".format(y_value)

        # Create annotation
        ax.annotate(
            label,                      # Use `label` as label
            (x_value, y_value),         # Place label at end of the bar
            xytext=(0, space),          # Vertically shift label by `space`
            textcoords="offset points", # Interpret `xytext` as offset in points
            ha='center',                # Horizontally center label
            va=va)                      # Vertically align label differently for
                                        # positive and negative values.
